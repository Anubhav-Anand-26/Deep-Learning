# %% [markdown]
# <a href="https://colab.research.google.com/github/Anubhav-Anand-26/Deep-Learning/blob/main/LAB1_DEEP_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pip
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:32: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(

# %%
pd.read_csv('/content/drive/MyDrive/DIABETES.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5      109             75             26        0  36.0
# 1              3      158             76             36      245  31.6
# 2              3       88             58             11       54  24.8
# 3              6       92             92              0        0  19.9
# 4             10      122             78             31        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 733           10      101             76             48      180  32.9
# 734            2      122             70             27        0  36.8
# 735            5      121             72             23      112  26.2
# 736            1      126             60              0        0  30.1
# 737            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.546   60        0
# ...

# %%
ls
# Out:
#  1602685091130.jpg
#  1602685091134.jpg
#  1602685165518.jpg
#  1606201932926.jpg
#  1606894197557.jpg
#  1606901755360.jpg
#  1608448198601.jpg
#  1608552459179.jpg
#  1608552527777.jpg
#  1609583091580.jpg
# 'Anubhav Anand_500105017_B2_Web Technology File.pdf'
# 'Anubhav Anand_500105017.docx'
# 'ANUBHAV CV.pdf'
# 'assessment dl.pdf'
# 'body language .aac'
# 'Colab Notebooks'/
# 'conversation living.aac'
#  DIABETES.csv
# 'Digital logic assignment 1 .pdf'
# 'Digital logic assignment -3.pdf'
# 'Driving license'
# 'DSA 1.pdf'
#  dsa_assignment3.pdf
# 'DSA online.pdf'
# 'flight ticket .pdf'
# 'HALL_TICKET (2).PDF'
#  IMG_20230207_144241.jpg
# 'IMG-20240221-WA0045 (1).jpg'
#  IMG-20240221-WA0045.jpg
# 'inspirational story 1.aac'
# 'IT vertical assignment 1 .pdf'
# 'IT_Verticals Assignment 3.mp4'
# 'lc 10.aac'
#  Lc.aac
# 'LC assignment 8.aac'
# 'LC feedback .aac'
# 'Lc presentation (Anubhav Anand).pptx'
# 'Mathematics assessment 1.pdf'
# 'Mathematics assignment 2 .pdf'
# ...

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
pd.read_csv('/content/drive/MyDrive/DIABETES.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5      109             75             26        0  36.0
# 1              3      158             76             36      245  31.6
# 2              3       88             58             11       54  24.8
# 3              6       92             92              0        0  19.9
# 4             10      122             78             31        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 733           10      101             76             48      180  32.9
# 734            2      122             70             27        0  36.8
# 735            5      121             72             23      112  26.2
# 736            1      126             60              0        0  30.1
# 737            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.546   60        0
# ...

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-2bb0b18689d4> in <cell line: 1>()
# ----> 1 data.describe()
#
# AttributeError: 'function' object has no attribute 'describe'

# %%
data=pd.read_csv('/content/drive/MyDrive/DIABETES.csv')

# %%
data.describe()
# Out:
#        Pregnancies    Glucose  BloodPressure  SkinThickness     Insulin  \
# count   738.000000  738.00000     738.000000     738.000000  738.000000
# mean      3.779133  120.52168      69.128726      20.659892   78.884824
# std       3.337424   31.90603      19.166937      15.908133  111.778233
# min       0.000000    0.00000       0.000000       0.000000    0.000000
# 25%       1.000000   99.00000      62.000000       0.000000    0.000000
# 50%       3.000000  117.00000      72.000000      23.000000   34.000000
# 75%       6.000000  140.00000      80.000000      32.000000  126.750000
# max      17.000000  199.00000     122.000000      99.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  738.000000                738.000000  738.000000  738.000000
# mean    32.007046                  0.472327   33.036585    0.338753
# std      7.856792                  0.327017   11.738791    0.473607
# ...
